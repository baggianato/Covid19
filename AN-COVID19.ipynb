# %% [markdown]
# # COVID-19 andamento nazionale - Raccolta e rappresentazione dati
#
# Il seguente codice intende soltanto raccogliere e mostrare i dati raccolti dal Dipartimento di Protezione Civile.
#
# **Nessuna analisi viene effettuata.**
#
# *fonte dati: https://github.com/pcm-dpc/COVID-19*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

# %%
dati = pd.read_csv('./dati/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv', parse_dates=['data'])
print('Last data update: ',dati['data'].max())
# Out:
# Last data update:  2020-04-08 17:00:00

# %%
chedato = [
    'totale_casi',
    'totale_positivi',
    'variazione_totale_positivi',
    'nuovi_positivi',
    'deceduti'    
]

# %%
plt.figure(figsize=(10,10))
locator = mdates.AutoDateLocator(interval_multiples=False)
formatter = mdates.AutoDateFormatter(locator)
plt.rc('font', size=15)
for tipodato in chedato:
    plt.plot(dati['data'], dati[tipodato], label=tipodato, marker='o', linestyle=':')
    plt.legend()
    plt.gca().xaxis.set_major_locator(locator)
    plt.gca().xaxis.set_major_formatter(formatter)
    plt.yscale('log')
    plt.grid(True)
    plt.xticks(rotation=30)
    plt.title('COVID-19 Andamento Nazionale I')
    plt.xlabel('Data')
    plt.ylabel('Numero di casi')
# Out:
# C:\Users\giacn\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
osp = [
    'dimessi_guariti',
    'terapia_intensiva',
    'ricoverati_con_sintomi',
    'isolamento_domiciliare',
    'totale_ospedalizzati',
    'tamponi'
]

# %%
plt.figure(figsize=(10,10))
plt.rc('font', size=15)
for tipoosp in osp:
    plt.plot(dati['data'], dati[tipoosp], label=tipoosp, marker='o', linestyle=':')
    plt.legend()
    plt.gca().xaxis.set_major_locator(locator)
    plt.gca().xaxis.set_major_formatter(formatter)
    plt.yscale('log')
    plt.grid(True)
    plt.xticks(rotation=30)
    plt.title('COVID-19 Andamento Nazionale II')
    plt.xlabel('Data')
    plt.ylabel('Numero di casi')
